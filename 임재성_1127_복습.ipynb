# %%
import pandas as pd

# %%
file_url = "https://drive.google.com/file/d/1MxTrAJivTprYPkKMIdhIGcqAA6wr0BSC/view?usp=share_link" #구글드라이브 csv파일 이미지 주소
file_path='https://drive.google.com/uc?id=' + file_url.split('/')[-2] #'/'로 구분했을 때 url_path의 뒤에서 두번째 값이 공유된 파일의 고유값

print("공유파일 링크변환 경로명 : ", file_path)
mpg = pd.read_csv(file_path)
# Out:
# 공유파일 링크변환 경로명 :  https://drive.google.com/uc?id=1MxTrAJivTprYPkKMIdhIGcqAA6wr0BSC

# %%
file_url = 'https://drive.google.com/file/d/15dVFh52Yseu8PGMtTDXk6XBxeG1kB8Za/view?usp=share_link' #구글드라이브 csv파일 이미지 주소
file_path='https://drive.google.com/uc?id=' + file_url.split('/')[-2] #'/'로 구분했을 때 url_path의 뒤에서 두번째 값이 공유된 파일의 고유값

print("공유파일 링크변환 경로명 : ", file_path)
gapminder = pd.read_csv(file_path, sep = '\t')
# Out:
# 공유파일 링크변환 경로명 :  https://drive.google.com/uc?id=15dVFh52Yseu8PGMtTDXk6XBxeG1kB8Za

# %%
display(mpg)
display(gapminder)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg[['trans', 'category']] # trans, category에 해당하는 컬럼 추출
# Out:
#           trans category
# 0      auto(l5)  compact
# 1    manual(m5)  compact
# 2    manual(m6)  compact
# 3      auto(av)  compact
# 4      auto(l5)  compact
# ..          ...      ...
# 229    auto(s6)  midsize
# 230  manual(m6)  midsize
# 231    auto(l5)  midsize
# 232  manual(m5)  midsize
# 233    auto(s6)  midsize
#
# [234 rows x 2 columns]

# %%
gapminder.loc[1700] # gapminder에서 인덱스가 1700인 행 추출
# Out:
# country        Zimbabwe
# continent        Africa
# year               1992
# lifeExp          60.377
# pop            10704340
# gdpPercap    693.420786
# Name: 1700, dtype: object

# %%
mpg.loc[230] # mpg에서 인덱스가 230인 행 추출
# Out:
# manufacturer    volkswagen
# model               passat
# displ                  2.0
# year                  2008
# cyl                      4
# trans           manual(m6)
# drv                      f
# cty                     21
# hwy                     29
# fl                       p
# category           midsize
# Name: 230, dtype: object

# %%
num_of_rows = gapminder.shape[0] # gapminder의 행의 개수를 새로운 변수 num_of_rows 에 저장
num_of_rows
# Out:
# 1704

# %%
num_of_index = num_of_rows - 4 
num_of_index
# Out:
# 1700

# %%
gapminder.loc[num_of_index] # loc은 변수로 데이터를 추출할 수도 있다.
# Out:
# country        Zimbabwe
# continent        Africa
# year               1992
# lifeExp          60.377
# pop            10704340
# gdpPercap    693.420786
# Name: 1700, dtype: object

# %%
gapminder.loc[num_of_rows - 1] # 직접 연산도 가능
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
gapminder.loc[num_of_rows - 1] == gapminder.loc[1703] # 각 컬럼별로 논리 연산자 반환
# Out:
# country      True
# continent    True
# year         True
# lifeExp      True
# pop          True
# gdpPercap    True
# Name: 1703, dtype: bool

# %%
gapminder.loc[[1, 20, 300, 1703]] # gapminder에서 인덱스가 1,20,300,1703인 행 추출
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 20        Albania    Europe  1992   71.581   3326498  2497.437901
# 300      Colombia  Americas  1952   50.643  12350771  2144.115096
# 1703     Zimbabwe    Africa  2007   43.487  12311143   469.709298

# %%
mpg.loc[[0, 1, 2, 3]] # mpg에서 인덱스가 0,1,2,3인 행 추출
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact

# %%
gapminder.iloc[0] # gapminder에서 행 번호가 0인 행 추출
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
mpg.iloc[230] # mpg에서 행 번호가 230인 행 추출
# Out:
# manufacturer    volkswagen
# model               passat
# displ                  2.0
# year                  2008
# cyl                      4
# trans           manual(m6)
# drv                      f
# cty                     21
# hwy                     29
# fl                       p
# category           midsize
# Name: 230, dtype: object

# %%
new_gapminder = gapminder.loc[[1, 20, 30, 1703]] # gapminder에서 인덱스가 1,20,300,1703인 행 추출하여 새로운 변수 new_gapminder에 저장
new_gapminder
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 20        Albania    Europe  1992   71.581   3326498  2497.437901
# 30        Algeria    Africa  1982   61.368  20033753  5745.160213
# 1703     Zimbabwe    Africa  2007   43.487  12311143   469.709298

# %%
new_gapminder.loc[20] #new_gapminder에서 인덱스가 20인 행을 추출
# Out:
# country          Albania
# continent         Europe
# year                1992
# lifeExp           71.581
# pop              3326498
# gdpPercap    2497.437901
# Name: 20, dtype: object

# %%
new_gapminder.iloc[20] # new_gapminder는 행이 4개 밖에 없으므로 행 번호가 20인 행은 존재하지 않음
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-96c6595bfe3c> in <module>
# ----> 1 new_gapminder.iloc[20]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
new_gapminder.loc[2] # new_gapminder에는 인덱스가 2인 행이 존재하지 않음
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
gapminder.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'category'],
#       dtype='object')

# %%
gapminder.loc[:, ['country', 'lifeExp']] # country와 lifeExp에 해당하는 컬럼과 그에 대응하는 행 전체를 추출
# Out:
#           country  lifeExp
# 0     Afghanistan   28.801
# 1     Afghanistan   30.332
# 2     Afghanistan   31.997
# 3     Afghanistan   34.020
# 4     Afghanistan   36.088
# ...           ...      ...
# 1699     Zimbabwe   62.351
# 1700     Zimbabwe   60.377
# 1701     Zimbabwe   46.809
# 1702     Zimbabwe   39.989
# 1703     Zimbabwe   43.487
#
# [1704 rows x 2 columns]

# %%
gapminder.loc[: , [1, 2, 3]] # loc에서 컬럼을 가지고 올 때 문자로만 컬럼을 정확하게 설명해야함
# Out:
#   File "<ipython-input-44-5e81845808db>", line 1
#     gapminder.loc[, [1, 2, 3]]
#                   ^
# SyntaxError: invalid syntax

# %%
gapminder.iloc[50:55, [1, 2, 3]] # iloc 에서 컬럼을 가지고 올 때는 열 번호도 가능
# Out:
#    continent  year  lifeExp
# 50  Americas  1962   65.142
# 51  Americas  1967   65.634
# 52  Americas  1972   67.065
# 53  Americas  1977   68.481
# 54  Americas  1982   69.942

# %%
gp_r = list(range(5))
gp_r
# Out:
# [0, 1, 2, 3, 4]

# %%
gapminder.loc[:, gp_r] # loc에서 컬럼을 가지고 올 때 문자로만 컬럼을 정확하게 설명해야함
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-3a4118bead77> in <module>
# ----> 1 gapminder.loc[:, gp_r]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
gapminder.iloc[:, gp_r] # iloc 에서 컬럼을 가지고 올 때는 열 번호가 저장된 변수도 가능
# Out:
#           country continent  year  lifeExp       pop
# 0     Afghanistan      Asia  1952   28.801   8425333
# 1     Afghanistan      Asia  1957   30.332   9240934
# 2     Afghanistan      Asia  1962   31.997  10267083
# 3     Afghanistan      Asia  1967   34.020  11537966
# 4     Afghanistan      Asia  1972   36.088  13079460
# ...           ...       ...   ...      ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418
# 1700     Zimbabwe    Africa  1992   60.377  10704340
# 1701     Zimbabwe    Africa  1997   46.809  11404948
# 1702     Zimbabwe    Africa  2002   39.989  11926563
# 1703     Zimbabwe    Africa  2007   43.487  12311143
#
# [1704 rows x 5 columns]

# %%
gapminder.iloc[:, : 3] # gapminder에서 컬럼 번호가 0,1,2인 컬럼과 그에 대응하는 행 전체를 추출
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.groupby('country')['gdpPercap'].mean() # country기준으로 그룹화 후 gdpPercap 평균 반환
# Out:
# country
# Afghanistan            802.674598
# Albania               3255.366633
# Algeria               4426.025973
# Angola                3607.100529
# Argentina             8955.553783
#                          ...
# Vietnam               1017.712615
# West Bank and Gaza    3759.996781
# Yemen, Rep.           1569.274672
# Zambia                1358.199409
# Zimbabwe               635.858042
# Name: gdpPercap, Length: 142, dtype: float64

# %%
gapminder_gr = gapminder.groupby(['year', 'continent'])[['pop', 'gdpPercap']].mean() # year기준으로 그룹화 후 다시 continent 기준으로 그룹화를 진행하여 pop과 gdpPercap 평균 반환

# %%
gapminder_gr
# Out:
#                          pop     gdpPercap
# year continent
# 1952 Africa     4.570010e+06   1252.572466
#      Americas   1.380610e+07   4079.062552
#      Asia       4.228356e+07   5195.484004
#      Europe     1.393736e+07   5661.057435
#      Oceania    5.343003e+06  10298.085650
# 1957 Africa     5.093033e+06   1385.236062
#      Americas   1.547816e+07   4616.043733
#      Asia       4.735699e+07   5787.732940
#      Europe     1.459635e+07   6963.012816
#      Oceania    5.970988e+06  11598.522455
# 1962 Africa     5.702247e+06   1598.078825
#      Americas   1.733081e+07   4901.541870
#      Asia       5.140476e+07   5729.369625
#      Europe     1.534517e+07   8365.486814
#      Oceania    6.641759e+06  12696.452430
# 1967 Africa     6.447875e+06   2050.363801
#      Americas   1.922986e+07   5668.253496
#      Asia       5.774736e+07   5971.173374
#      Europe     1.603930e+07  10143.823757
#      Oceania    7.300207e+06  14495.021790
# ...

# %%
gapminder_gr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 60 entries, (1952, 'Africa') to (2007, 'Oceania')
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pop        60 non-null     float64
#  1   gdpPercap  60 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gapminder_gdp = gapminder.groupby('year')['gdpPercap'].mean()

# %%
gapminder_gdp.plot() # 연도에 따른 gdp평균의 변화를 관찰하기 위해 시각화

# %%
#시리즈 만들어보기
s = pd.Series(['안녕','안녕하세요'])
s
# Out:
# 0       안녕
# 1    안녕하세요
# dtype: object

# %%
#데이터 프레임 만들어보기
df = pd.DataFrame({
    'Name':['홍길동','임꺽정','김영희'],
    '나이':[11,12,13]
},
index = ['1반','2반','3반']) # 인덱스를 직접 지정할 수 있음

df
# Out:
#    Name  나이
# 1반  홍길동  11
# 2반  임꺽정  12
# 3반  김영희  13
