# %%
# 한글 폰트
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## 재무제표 이해하기
# - 매출액: 영업활동을 통해 얻은 총수익 (예, 1000원짜리 물건 100개를 팔았을 때 매출액은 10만원).
#  - 매출액 = 판매가격 * 판매량
#
# - 영업이익: 영업활동을 통해 순수하게 남은 이익 (예, 매출액 10만원, 원가 3만원, 관리비 2만원일 경우, 영업이익은 5만원)
#  - 영업이익 = 매출액 - 매출원과 - 판매관리비
#
# - 당기순이익: 기업이 한 해 동안 벌어들인 총수익(매출액, 영업외수익)에서 총비용(매출원가, 판매비와관리비, 영업외비용, 법인세비용)을 차감한 최종 이익.
#  - 손익계산서 상에서 최종적으로 산출되는 이익.
#
# - 영업이익률: 매출액 대비 영업이익의 비중을 나타낸 수치로 영업활동을 통해서 벌어들은 수익의 비중.
#  - 영업이익률 = (영업이익 / 매출액) * 100(%)
#
# - 순이익률: 매출액 중 주주에게 돌아가는 순이익의 비중.
#  - 순이익률 = (순이익 / 매출액) * 100(%)
#
# - ROE (Return On Equity - 자기자본이익률): 투입한 자기자본이 얼마만큼의 이익을 냈는지 나타내는 지표. 기업이 자기자본(주주지분)을 활용해 1년간 얼마나 벌어들였는가를 나타내는 대표적 수익성 지표로 경영효율성을 표시해 줌
#  - 자기자본이익률 = (당기순이익 / 평균 자기자본) * 100(%)
#
# - 부채비율: 기업의 재무 안정성을 나타내는 대표적은 재무비율로써 일반적으로 100% 이하이면 매우 안전, ​200% 이하이면 큰 문제는 없다고 간주됨.부채비율은 부채총계를 자본총계로 나눈 값이며 타인자본의 의존도를 나타냄.
#  - 부채비율 = (부채총계 / 자본총계) * 100%
#
# - 당좌비율: 회사의 단기 유동성을 평가하는 지표로, 회사의 가장 유동화(현금화) 하기 쉬운 자산이 얼마나 단기 채무에 충당될 수 있는가를 측정하는 비율.
#  - 당좌비율 = (당좌자산 / 유동부채) * 100%
#
# - 유보율: 기업의 잉여금을 납입자본금으로 나눈 비율로, 회사 내에 얼마나 많은 자금을 보유하고 있는지 알 수 있는 지표. 기업의 이익잉여금(영업활동 등의 이익창출 활동을 통해 획득한 이익)과 자본잉여금(자본거래에 의해 획득한 이익)을 합한 전체잉여금을 납입자본금으로 나눈 비율.
#  - 유보율: ((이익잉여금+자본잉여금) / 납입자본금) * 100%
#
# - EPS (Earning Per Share - 주당순이익): 주식 한주에 포함된 이익이 얼마인지 보여주는 지표.
# EPS가 높으면 경영실적이 양호하고 투자가치가 크다는 의미로 배당이 증가할 가능성도 높음.
#  - 주당순이익 = 당기순이익 / 총 발행주식수
#  - EPS가 높을수록 기업이 돈을 많이 벌었음.
#
# - PER (Price Earning Ratio - 주가수익비율):  주가를 주당순이익(EPS)로 나눈 값. 투자자가 초기 투자 금액을 다시 벌어들이는데 걸리는 시간 (예, PER 10인 경우 초기 투자 금액을 벌기 위해서는 10년이 걸린다는 의미).
#  - 주가수익비율 = 주가 / 주당순이익
#  - PER이 낮을수록 기업이 내는 순이익에 비해 현재 주가가 저평가되어 있음.
#
# - BPS (Book-value Per Share - 주당순자산가치): 만약 기업이 지금 당장 모든 활동을 중단하고 기업의 자산을 주주들에게 나눠줄 경우, 한 주당 얼마씩 돌아가는지 나태 내는 지표 (예, A기업의 순자산이 8억이고 1만주의 주식을 발행했다면, 주당순자산가치는 80,000만원).
#  - 주당순자산가치 = 기업의 현재 순자산 / 총 발행주식수
#  - BPS가 낮을수록 저평가되어 있음.
#
# - PBR (Price Book-value Ratio - 주가순자산비율): 현재 주가와 BPS의 비율을 나타낸 지표 (예, A기업의 BPS가 8만원이고, 현재 주가가 80만원이면 A기업의 PBR은 10배임).
#  - 주가순자산비율 = 현재주가 / 현재 주당순자산가치
#  - 동종업계의 PBR과 비교하여 낮을수록 저평가되어 있음.
#
# - 주당배당금: 주주가 보유 주식 한 주당 받을 수 있는 배당금 (예, 주당배당금이 1만원일 경우 주식 10주를 보유하면 10만원의 배당금을 받을 수 있음).
#  - 주당배당금 = 총 배당금 / 발행주식수
#  - 주당배당금이 높은수록 많이 배당을 받을 수 있음.
#
# - 시가배당율: 현재 주가에 대한 배당금의 비율 (예, 배당 기준일에 주가가 1만원이고 주당배당금이 500원이라면 시가배당률은 5%임).
#  - 시가배당율 = (주당배당금 / 배당기준일의 주가) * 100%
#  - 시가배당률이 높을수록 투자자의 기대수익률이 함께 높아짐.
#
# - 배당성향: 현금 배당금의 총합이 당기순이익에서 차지하는 비율 (예, 당기순이익이 100만원이고 현금배당을 30만원 실시하면, 해당 기업의 배당성향은 30%).
#  - 배당성향 = (총현금 배당금/당기순이익) * 100%
#  - 배당성향이 높은 기업이 배당을 잘 주는 좋은 기업이지만, 이익금을 배당에 쓰면 미래를 위해 투자여력이 없을 수도 있음.

# %% [markdown]
# # 분석기업: 현대미포조선(010620)
# - 중형 석유화학제품운반선(PC)을 비롯해 총 8종의 선박이 세계 시장점유율 1위를 기록 중
# - 한국조선해양(009540)의 자회사
# - 경쟁사: 대우조선해양(042660), 삼성중공업(010140)

# %% [markdown]
# ### 재무제표 크롤링

# %%
# 네이버증권에서 재무제표 크롤링
import pandas as pd
import requests
code = '010620'
URL = f"https://finance.naver.com/item/main.naver?code={code}"
r = requests.get(URL)
df = pd.read_html(r.text)[3]   # 단순하게 URL에서 html 가져와서 테이블은 pandas로 가져올 수 있으므로 pandas로 넘겨서 table로 나오게 함

# %%
df
# Out:
#        주요재무정보  최근 연간 실적                               최근 분기 실적            \
#        주요재무정보   2019.12 2020.12   2021.12 2022.12(E)   2021.09   2021.12
#        주요재무정보    IFRS연결  IFRS연결    IFRS연결     IFRS연결    IFRS연결    IFRS연결
# 0         매출액  29941.00   27920  28872.00   36304.00   6194.00   8605.00
# 1        영업이익    926.00     367  -2173.00    -345.00    343.00   -770.00
# 2       당기순이익    612.00    -123  -1601.00     899.00    353.00   -784.00
# 3       영업이익률      3.09    1.31     -7.53      -0.95      5.53     -8.95
# 4        순이익률      2.04   -0.44     -5.54       2.48      5.70     -9.11
# 5   ROE(지배주주)      2.31   -0.84     -7.11       4.18     -6.67     -7.11
# 6        부채비율     43.61   52.02     75.94        NaN     72.30     75.94
# 7        당좌비율     58.75   83.95     54.62        NaN     81.09     54.62
# 8         유보율    964.36  943.80    859.07        NaN    903.56    859.07
# 9      EPS(원)   1333.00    -488  -3998.00    2318.00    957.00  -1984.00
# ...

# %%
df.columns
# Out:
# MultiIndex([(  '주요재무정보',     '주요재무정보', '주요재무정보'),
#             ('최근 연간 실적',    '2019.12', 'IFRS연결'),
#             ('최근 연간 실적',    '2020.12', 'IFRS연결'),
#             ('최근 연간 실적',    '2021.12', 'IFRS연결'),
#             ('최근 연간 실적', '2022.12(E)', 'IFRS연결'),
#             ('최근 분기 실적',    '2021.09', 'IFRS연결'),
#             ('최근 분기 실적',    '2021.12', 'IFRS연결'),
#             ('최근 분기 실적',    '2022.03', 'IFRS연결'),
#             ('최근 분기 실적',    '2022.06', 'IFRS연결'),
#             ('최근 분기 실적',    '2022.09', 'IFRS연결'),
#             ('최근 분기 실적', '2022.12(E)', 'IFRS연결')],
#            )

# %% [markdown]
# #### Data PreProcessing

# %%
df.set_index(df.columns[0], inplace = True) # 인덱스를 첫번째 컬럼으로 지정
df.head()
# Out:
#                           최근 연간 실적                              최근 분기 실적  \
#                            2019.12 2020.12   2021.12 2022.12(E)  2021.09
#                             IFRS연결  IFRS연결    IFRS연결     IFRS연결   IFRS연결
# (주요재무정보, 주요재무정보, 주요재무정보)
# 매출액                       29941.00   27920  28872.00   36304.00  6194.00
# 영업이익                        926.00     367  -2173.00    -345.00   343.00
# 당기순이익                       612.00    -123  -1601.00     899.00   353.00
# 영업이익률                         3.09    1.31     -7.53      -0.95     5.53
# 순이익률                          2.04   -0.44     -5.54       2.48     5.70
#
#
#                           2021.12  2022.03  2022.06  2022.09 2022.12(E)
#                            IFRS연결   IFRS연결   IFRS연결   IFRS연결     IFRS연결
# (주요재무정보, 주요재무정보, 주요재무정보)
# 매출액                       8605.00  8760.00  9354.00  8823.00    9324.00
# 영업이익                      -770.00  -618.00   -66.00   141.00     235.00
# ...

# %%
df.index.rename('주요재무정보', inplace = True) # (주요재무정보, 주요재무정보, 주요재무정보)를 주요재무정보로 변경
df.head()
# Out:
#         최근 연간 실적                              최근 분기 실적                    \
#          2019.12 2020.12   2021.12 2022.12(E)  2021.09  2021.12  2022.03
#           IFRS연결  IFRS연결    IFRS연결     IFRS연결   IFRS연결   IFRS연결   IFRS연결
# 주요재무정보
# 매출액     29941.00   27920  28872.00   36304.00  6194.00  8605.00  8760.00
# 영업이익      926.00     367  -2173.00    -345.00   343.00  -770.00  -618.00
# 당기순이익     612.00    -123  -1601.00     899.00   353.00  -784.00  -395.00
# 영업이익률       3.09    1.31     -7.53      -0.95     5.53    -8.95    -7.06
# 순이익률        2.04   -0.44     -5.54       2.48     5.70    -9.11    -4.50
#
#
#         2022.06  2022.09 2022.12(E)
#          IFRS연결   IFRS연결     IFRS연결
# 주요재무정보
# 매출액     9354.00  8823.00    9324.00
# 영업이익     -66.00   141.00     235.00
# 당기순이익    375.00  1073.00     280.00
# 영업이익률     -0.71     1.59       2.52
# 순이익률       4.00    12.16       3.01

# %%
df.columns = df.columns.droplevel(2) #컬럼은 (0,1,2) 형식의 튜플로 되어있으니 2번째를 droplevel을 하여 IFRS연결을 삭제
df.head()
# Out:
#         최근 연간 실적                              최근 분기 실적                    \
#          2019.12 2020.12   2021.12 2022.12(E)  2021.09  2021.12  2022.03
# 주요재무정보
# 매출액     29941.00   27920  28872.00   36304.00  6194.00  8605.00  8760.00
# 영업이익      926.00     367  -2173.00    -345.00   343.00  -770.00  -618.00
# 당기순이익     612.00    -123  -1601.00     899.00   353.00  -784.00  -395.00
# 영업이익률       3.09    1.31     -7.53      -0.95     5.53    -8.95    -7.06
# 순이익률        2.04   -0.44     -5.54       2.48     5.70    -9.11    -4.50
#
#
#         2022.06  2022.09 2022.12(E)
# 주요재무정보
# 매출액     9354.00  8823.00    9324.00
# 영업이익     -66.00   141.00     235.00
# 당기순이익    375.00  1073.00     280.00
# 영업이익률     -0.71     1.59       2.52
# 순이익률       4.00    12.16       3.01

# %%
# 연간 실적과 분기 실적 나누기
annual_date = pd.DataFrame(df).xs('최근 연간 실적', axis = 1)
quarter_date = pd.DataFrame(df).xs('최근 분기 실적', axis = 1)  # xs는 멀티인덱스 객체에 대해서 하위 분류를 출력하는 메서드

# %%
display(annual_date)
display(quarter_date)
# Out:
#             2019.12 2020.12   2021.12  2022.12(E)
# 주요재무정보
# 매출액        29941.00   27920  28872.00    36304.00
# 영업이익         926.00     367  -2173.00     -345.00
# 당기순이익        612.00    -123  -1601.00      899.00
# 영업이익률          3.09    1.31     -7.53       -0.95
# 순이익률           2.04   -0.44     -5.54        2.48
# ROE(지배주주)      2.31   -0.84     -7.11        4.18
# 부채비율          43.61   52.02     75.94         NaN
# 당좌비율          58.75   83.95     54.62         NaN
# 유보율          964.36  943.80    859.07         NaN
# EPS(원)      1333.00    -488  -3998.00     2318.00
# PER(배)        34.54  -98.36    -17.51       34.39
# BPS(원)     58106.00   58333  54249.00    56690.00
# PBR(배)         0.79    0.82      1.29        1.41
# 주당배당금(원)     350.00       -       NaN      168.00
# 시가배당률(%)       0.76       -       NaN         NaN
# 배당성향(%)       26.21       -       NaN         NaN
#             2021.09   2021.12   2022.03   2022.06   2022.09  2022.12(E)
# 주요재무정보
# ...

# %% [markdown]
# ### 관점에 따른 시각화
# - 수익성: 매출액, 영업이익, 당기순이익  영업이익률, 순이익률, ROE(자기자본이익률)
# - 재무위험: 부채비율, 당좌비율
# - 시장가치: PER, PBR

# %%
new_quarter_date = quarter_date.transpose().reset_index().rename(columns = {'index' : '날짜'}) # 시각화를 위해 앞서 주가 테이블처럼 변형
new_quarter_date
# Out:
# 주요재무정보          날짜     매출액   영업이익   당기순이익  영업이익률   순이익률  ROE(지배주주)    부채비율  \
# 0          2021.09  6194.0  343.0   353.0   5.53   5.70      -6.67   72.30
# 1          2021.12  8605.0 -770.0  -784.0  -8.95  -9.11      -7.11   75.94
# 2          2022.03  8760.0 -618.0  -395.0  -7.06  -4.50     -10.20   93.74
# 3          2022.06  9354.0  -66.0   375.0  -0.71   4.00      -1.92   99.23
# 4          2022.09  8823.0  141.0  1073.0   1.59  12.16       1.19  117.82
# 5       2022.12(E)  9324.0  235.0   280.0   2.52   3.01        NaN     NaN
#
# 주요재무정보   당좌비율     유보율  EPS(원)  PER(배)   BPS(원)  PBR(배)  주당배당금(원)  시가배당률(%)  \
# 0       81.09  903.56   957.0  -18.16  56425.0    1.24       NaN       NaN
# 1       54.62  859.07 -1984.0  -17.51  54249.0    1.29       NaN       NaN
# 2       61.03  840.07 -1032.0  -13.68  53339.0    1.47       NaN       NaN
# 3       59.83  860.16  1004.0  -86.36  54422.0    1.67       NaN       NaN
# ...

# %%
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(3, 2)

# %%
# 수익성 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5) 

fin_features =  ['매출액', '영업이익', '당기순이익', '영업이익률', '순이익률', 'ROE(지배주주)']
color = ['r', 'b', 'g', 'orange', 'skyblue', 'purple']

import seaborn as sns

for idx, feature in enumerate(fin_features):
  ax = plt.subplot(grid[idx])
  sns.lineplot(data = new_quarter_date,
               x = '날짜',
               y = feature,
               color = color[idx], 
               ax = ax) 
  ax.set_title(f'{feature}')
  plt.xticks(rotation = 90)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
grid = gridspec.GridSpec(2, 1)

# %%
# 재무위험 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

fin_features_2 =  ['부채비율', '당좌비율']
color = ['r', 'b']

for idx, feature in enumerate(fin_features_2): 
  ax = plt.subplot(grid[idx])
  sns.lineplot(data = new_quarter_date,
               x = '날짜',
               y = feature,
               color = color[idx], 
               ax = ax) 
  ax.set_title(f'{feature}')
  plt.xticks(rotation = 90)
  
  if idx == 0:
    plt.axhline(100, color='g', linestyle='--', linewidth = 2) 
    plt.axhline(200, color='r', linestyle='--', linewidth = 2) # 부채비율의 임계점인 100과 200을 표시

# %%
grid = gridspec.GridSpec(2, 1)

# %%
# 시장가치 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

fin_features_3 = ['PER(배)', 'PBR(배)']
color = ['orange', 'purple']

for idx, feature in enumerate(fin_features_3):
  ax = plt.subplot(grid[idx])
  sns.lineplot(data = new_quarter_date,
               x = '날짜',
               y = feature,
               color = color[idx],
               ax = ax)
  ax.set_title(f'{feature}')
  plt.xticks(rotation = 90)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 주가 불러오기

# %%
# !pip install -U finance-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import FinanceDataReader as fdr

# %%
code = '010620'
stock = fdr.DataReader(code, '2021-09') # fdr 모듈에서 DataReader 메서드를 이용하여 주가 불러오기
stock.reset_index(inplace = True)

# %%
stock.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Change'], dtype='object')

# %% [markdown]
# ### 주가 시각화

# %%
grid = gridspec.GridSpec(3, 2)

# %%
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5) # 그래프 간의 거리 조절

stock_features =  ['Open', 'High', 'Low', 'Close', 'Volume', 'Change'] 
color = ['r', 'b', 'g', 'orange', 'skyblue', 'purple']

for idx, feature in enumerate(stock_features):  # index와 같이 나오게 하는 반복문
  ax = plt.subplot(grid[idx])
  sns.lineplot(data = stock,
               x = 'Date',
               y = feature,
               color = color[idx], 
               ax = ax) 
  ax.set_title(f'{feature}')
  plt.xticks(rotation = 90)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### [추가study] 주가 크롤링
# 추가적으로 주가를 크롤링하는 방법을 공부하기 위해 진행함

# %%
import ast
import pandas as pd
import requests
# 간단하게는 HTTP, HTTPS 웹 사이트에 요청하기 위해 자주 사용되는 모듈 중 하나이고 Crawling 과정에서 requests모듈을 이용해 웹 사이트의 소스코드를 가져온 다음 파싱을 하는 경우가 많음
# 파싱(parsing): 어떤 큰 자료에서 원하는 정보만 가공하고 뽑아서 원하는 때에 불러올 수 있게 하는 것
# requests 모듈은 [PUT, GET, POST, HEAD, PATCH, DELETE, OPTIONS] 메서드가 존재

# %%
url_crw = 'https://api.finance.naver.com/siseJson.naver'
code = '010620'
params = {
    'symbol': f'{code}',  # 현대미포조선
    'requestType': 1,  # 무엇인지 모르겠음
    'startTime': '20210901',
    'endTime': '20221231',
    'timeframe': 'day',  # 'week', 'month'
}

# %%
res = requests.get(url_crw, params=params) # params 매개변수는 튜플(tuple), 딕셔너리(dict)형식으로 매개변수에 넣으면 양식이 URL 인코딩이 되어 URL에 추가됨
print(res) # 200은 요청이 성공적으로 수행되었음을 나타냄
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
#  [['날짜', '시가', '고가', '저가', '종가', '거래량', '외국인소진율'],
#
#
#
#
# ["20210901", 76400, 77400, 74500, 75000, 281001, 10.58],
#
# ["20210902", 74900, 75600, 73100, 73800, 284997, 10.67],
#
# ["20210903", 74300, 75000, 73300, 73700, 227234, 10.72],
#
# ["20210906", 73800, 75300, 73000, 73600, 234175, 10.66],
#
# ["20210907", 73900, 75500, 73200, 75500, 301384, 10.83],
#
# ["20210908", 75000, 75300, 73000, 73800, 326909, 10.81],
#
# ["20210909", 73300, 73300, 70000, 70400, 686608, 10.43],
#
# ["20210910", 70800, 73900, 70600, 73800, 375203, 10.68],
#
# ["20210913", 74200, 74500, 72300, 72900, 221386, 10.72],
#
# ["20210914", 73000, 77500, 73000, 77100, 600686, 11.22],
#
# ["20210915", 76400, 77300, 75500, 76700, 189371, 11.18],
#
# ["20210916", 77800, 79400, 75900, 77700, 390932, 10.97],
#
# ["20210917", 77800, 78000, 72000, 72300, 1042641, 10.37],
#
# ["20210923", 71000, 72300, 70500, 71500, 260519, 10.42],
#
# ["20210924", 71700, 73500, 70500, 70700, 315208, 10.37],
#
# ...

# %% [markdown]
# #### Data PreProcessing

# %%
data_crw = res.text.strip()  # strip 메서드를 이용하여 공백을 제거
data_crw
# Out:
# '[[\'날짜\', \'시가\', \'고가\', \'저가\', \'종가\', \'거래량\', \'외국인소진율\'],\n\n\t\n\t\n\t\t\n["20210901", 76400, 77400, 74500, 75000, 281001, 10.58],\n\t\t\n["20210902", 74900, 75600, 73100, 73800, 284997, 10.67],\n\t\t\n["20210903", 74300, 75000, 73300, 73700, 227234, 10.72],\n\t\t\n["20210906", 73800, 75300, 73000, 73600, 234175, 10.66],\n\t\t\n["20210907", 73900, 75500, 73200, 75500, 301384, 10.83],\n\t\t\n["20210908", 75000, 75300, 73000, 73800, 326909, 10.81],\n\t\t\n["20210909", 73300, 73300, 70000, 70400, 686608, 10.43],\n\t\t\n["20210910", 70800, 73900, 70600, 73800, 375203, 10.68],\n\t\t\n["20210913", 74200, 74500, 72300, 72900, 221386, 10.72],\n\t\t\n["20210914", 73000, 77500, 73000, 77100, 600686, 11.22],\n\t\t\n["20210915", 76400, 77300, 75500, 76700, 189371, 11.18],\n\t\t\n["20210916", 77800, 79400, 75900, 77700, 390932, 10.97],\n\t\t\n["20210917", 77800, 78000, 72000, 72300, 1042641, 10.37],\n\t\t\n["20210923", 71000, 72300, 70500, 71500, 260519, 10.42],\n\t\t\n["20210924", 71700,
# ...

# %%
stock_crw = ast.literal_eval(data_crw) # 문자열을 배열로 변환
stock_crw
# Out:
# [['날짜', '시가', '고가', '저가', '종가', '거래량', '외국인소진율'],
#  ['20210901', 76400, 77400, 74500, 75000, 281001, 10.58],
#  ['20210902', 74900, 75600, 73100, 73800, 284997, 10.67],
#  ['20210903', 74300, 75000, 73300, 73700, 227234, 10.72],
#  ['20210906', 73800, 75300, 73000, 73600, 234175, 10.66],
#  ['20210907', 73900, 75500, 73200, 75500, 301384, 10.83],
#  ['20210908', 75000, 75300, 73000, 73800, 326909, 10.81],
#  ['20210909', 73300, 73300, 70000, 70400, 686608, 10.43],
#  ['20210910', 70800, 73900, 70600, 73800, 375203, 10.68],
#  ['20210913', 74200, 74500, 72300, 72900, 221386, 10.72],
#  ['20210914', 73000, 77500, 73000, 77100, 600686, 11.22],
#  ['20210915', 76400, 77300, 75500, 76700, 189371, 11.18],
#  ['20210916', 77800, 79400, 75900, 77700, 390932, 10.97],
#  ['20210917', 77800, 78000, 72000, 72300, 1042641, 10.37],
#  ['20210923', 71000, 72300, 70500, 71500, 260519, 10.42],
#  ['20210924', 71700, 73500, 70500, 70700, 315208, 10.37],
# ...

# %%
stock_crw = pd.DataFrame(stock_crw, columns = stock_crw[0]) # 첫번째 원소를 컬럼으로 하는 데이터프레임으로 변환
stock_crw
# Out:
#            날짜     시가     고가     저가     종가     거래량  외국인소진율
# 0          날짜     시가     고가     저가     종가     거래량  외국인소진율
# 1    20210901  76400  77400  74500  75000  281001   10.58
# 2    20210902  74900  75600  73100  73800  284997   10.67
# 3    20210903  74300  75000  73300  73700  227234   10.72
# 4    20210906  73800  75300  73000  73600  234175   10.66
# ..        ...    ...    ...    ...    ...     ...     ...
# 324  20221223  88400  88400  85300  85300  263048   20.46
# 325  20221226  85300  85400  81900  84100  280678   20.55
# 326  20221227  84300  85900  82900  85500  232201   20.69
# 327  20221228  85500  88700  85200  87500  233680   20.74
# 328  20221229  86700  87900  83600  84500  172811   20.65
#
# [329 rows x 7 columns]

# %%
# stock_.drop(index = 0, inplace = True).reset_index(drop = True)
# df.drop does not return anything when inplace is set to True. It modifies the DataFrame in place and returns None. You don't need to create new names for them.

# %%
stock_crw.drop(index = 0, inplace = True) # 컬럼 이름으로 설정된 첫번째 행의 데이터를 삭제

# %%
stock_crw.reset_index(drop = True, inplace = True) # 인덱스를 0부터 설정
stock_crw
# Out:
#            날짜     시가     고가     저가     종가     거래량 외국인소진율
# 0    20210901  76400  77400  74500  75000  281001  10.58
# 1    20210902  74900  75600  73100  73800  284997  10.67
# 2    20210903  74300  75000  73300  73700  227234  10.72
# 3    20210906  73800  75300  73000  73600  234175  10.66
# 4    20210907  73900  75500  73200  75500  301384  10.83
# ..        ...    ...    ...    ...    ...     ...    ...
# 323  20221223  88400  88400  85300  85300  263048  20.46
# 324  20221226  85300  85400  81900  84100  280678  20.55
# 325  20221227  84300  85900  82900  85500  232201  20.69
# 326  20221228  85500  88700  85200  87500  233680  20.74
# 327  20221229  86700  87900  83600  84500  172811  20.65
#
# [328 rows x 7 columns]

# %%
# 컬럼 type 지정
stock_crw['날짜'] = pd.to_datetime(stock_crw['날짜']) # 날짜 컬럼을 날짜 형식으로 변환
col_numeric = ['시가', '고가', '저가', '종가', '거래량'] 
stock_crw[col_numeric] = stock_crw[col_numeric].apply(pd.to_numeric) # numeric type의 컬럼을 numeric type으로 변환
stock_crw['외국인소진율'] = stock_crw['외국인소진율'].astype('float64') # 외국인소진율 컬럼을 부동소숫점 형식으로 지정

# %%
stock_crw
# Out:
#             날짜     시가     고가     저가     종가     거래량  외국인소진율
# 0   2021-09-01  76400  77400  74500  75000  281001   10.58
# 1   2021-09-02  74900  75600  73100  73800  284997   10.67
# 2   2021-09-03  74300  75000  73300  73700  227234   10.72
# 3   2021-09-06  73800  75300  73000  73600  234175   10.66
# 4   2021-09-07  73900  75500  73200  75500  301384   10.83
# ..         ...    ...    ...    ...    ...     ...     ...
# 323 2022-12-23  88400  88400  85300  85300  263048   20.46
# 324 2022-12-26  85300  85400  81900  84100  280678   20.55
# 325 2022-12-27  84300  85900  82900  85500  232201   20.69
# 326 2022-12-28  85500  88700  85200  87500  233680   20.74
# 327 2022-12-29  86700  87900  83600  84500  172811   20.65
#
# [328 rows x 7 columns]

# %% [markdown]
# #### 주가 시각화

# %%
grid = gridspec.GridSpec(3, 2) # 그래프를 그릴 도화지 갯수

# %%
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5) # 그래프 간의 거리 조절

stock_features =  ['시가', '고가', '저가', '종가', '거래량', '외국인소진율'] 
color = ['r', 'b', 'g', 'orange', 'skyblue', 'purple']

for idx, feature in enumerate(stock_features):  # index와 같이 나오게 하는 반복문
  ax = plt.subplot(grid[idx])
  sns.lineplot(data = stock_crw,
               x = '날짜',
               y = feature,
               color = color[idx], 
               ax = ax) # hue 범례
  ax.set_title(f'{feature}')
  plt.xticks(rotation = 90)

# %% [markdown]
# ## 한국조선해양(009540)

# %%
code = '009540'
URL = f"https://finance.naver.com/item/main.naver?code={code}"
r = requests.get(URL)
df_1 = pd.read_html(r.text)[3]

# %%
df_1.set_index(df_1.columns[0], inplace = True) # 인덱스를 첫번째 컬럼으로 지정
df_1.index.rename('주요재무정보', inplace = True) # (주요재무정보, 주요재무정보, 주요재무정보)를 주요재무정보로 변경
df_1.columns = df_1.columns.droplevel(2) #컬럼은 (0,1,2) 형식의 튜플로 되어있으니 2번째를 droplevel을 하여 IFRS연결을 삭제

# 연간 실적과 분기 실적 나누기
annual_date_1 = pd.DataFrame(df_1).xs('최근 연간 실적', axis = 1)
quarter_date_1 = pd.DataFrame(df_1).xs('최근 분기 실적', axis = 1)  # xs는 멀티인덱스 객체에 대해서 하위 분류를 출력하는 메서드

# %%
display(annual_date_1)
display(quarter_date_1)
# Out:
#            2019.12  2020.12    2021.12 2022.12(E)
# 주요재무정보
# 매출액         151826   149037  154934.00     179455
# 영업이익          2902      744  -13848.00      -3861
# 당기순이익         2131    -8352  -11412.00        497
# 영업이익률         1.91     0.50      -8.94      -2.15
# 순이익률          1.40    -5.60      -7.37       0.28
# ROE(지배주주)     1.40    -7.42      -8.95       0.56
# 부채비율         93.83   103.23     119.86        NaN
# 당좌비율         60.52    71.38      66.38        NaN
# 유보율        5274.30  5035.69    4766.69        NaN
# EPS(원)        2318   -11781  -13131.00        769
# PER(배)       54.56    -9.21      -7.20     102.45
# BPS(원)      163572   154230  139385.00     137396
# PBR(배)        0.77     0.70       0.68       0.57
# 주당배당금(원)         -        -        NaN          -
# 시가배당률(%)         -        -        NaN        NaN
# 배당성향(%)          -        -        NaN        NaN
#              2021.09    2021.12    2022.03    2022.06    2022.09  2022.12(E)
# 주요재무정보
# ...

# %%
new_quarter_date_1 = quarter_date_1.transpose().reset_index().rename(columns = {'index' : '날짜'}) # 시각화를 위해 앞서 주가 테이블처럼 변형
new_quarter_date_1
# Out:
# 주요재무정보          날짜      매출액    영업이익   당기순이익  영업이익률   순이익률  ROE(지배주주)    부채비율  \
# 0          2021.09  35580.0  1418.0  1926.0   3.98   5.41     -11.72  107.68
# 1          2021.12  44566.0 -6968.0 -6753.0 -15.63 -15.15      -8.95  119.86
# 2          2022.03  39077.0 -3964.0 -2932.0 -10.14  -7.50     -11.66  129.62
# 3          2022.06  41886.0 -2651.0 -1056.0  -6.33  -2.52      -6.92  145.14
# 4          2022.09  42644.0  1887.0  3158.0   4.43   7.41      -6.34  164.64
# 5       2022.12(E)  54020.0  1051.0   496.0   1.95   0.92        NaN     NaN
#
# 주요재무정보   당좌비율      유보율  EPS(원)  PER(배)    BPS(원)  PBR(배)  주당배당금(원)  시가배당률(%)  \
# 0       86.44  4924.55  2465.0   -5.60  147014.0    0.69       NaN       NaN
# 1       66.38  4766.69 -7344.0   -7.20  139385.0    0.68       NaN       NaN
# 2       61.59  4710.29 -3274.0   -5.22  136597.0    0.65       NaN       NaN
# 3       57.82  4694.78 -1648.0   -9.58  135585.0    0.69       NaN       NaN
# ...

# %% [markdown]
# ### 자회사 관계에 있는 두 회사의 재무제표 상태 비교 시각화

# %%
grid = gridspec.GridSpec(2, 1)

# %%
# 수익성 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5) 

fin_subsidiary = [new_quarter_date, new_quarter_date_1]
company = ['현대미포조선', '한국조선해양']
fin_features =  ['매출액', '영업이익', '당기순이익', '영업이익률', '순이익률', 'ROE(지배주주)']
for idx, data in enumerate(fin_subsidiary):
    ax = plt.subplot(grid[idx])
    for feature in fin_features:
        sns.lineplot(data = data,
                     x = '날짜',
                     y = feature, 
                     ax = ax) 
        plt.legend(labels = fin_features)
    ax.set_title(f'{company[idx]}')
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
grid = gridspec.GridSpec(2, 1)

# %%
# 재무위험 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

fin_features_2 =  ['부채비율', '당좌비율']
for idx, data in enumerate(fin_subsidiary):
    ax = plt.subplot(grid[idx])
    for feature in fin_features_2:
        sns.lineplot(data = data,
                     x = '날짜',
                     y = feature, 
                     ax = ax) 
        plt.legend(labels = fin_features_2)
    ax.set_title(f'{company[idx]}')
    plt.axhline(100, color='g', linestyle='--', linewidth = 2) 
    plt.axhline(200, color='r', linestyle='--', linewidth = 2) # 부채비율의 임계점인 100과 200을 표시

# %%
grid = gridspec.GridSpec(2, 1)

# %%
# 시장가치 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

fin_features_3 = ['PER(배)', 'PBR(배)']
for idx, data in enumerate(fin_subsidiary):
    ax = plt.subplot(grid[idx])
    for feature in fin_features_3:
        sns.lineplot(data = data,
                     x = '날짜',
                     y = feature, 
                     ax = ax) 
        plt.legend(labels = fin_features_3)
    ax.set_title(f'{company[idx]}')
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 한국조선해양은 현대중공업그룹의 조선 부문 중간지주사로 현대미포조선 42.40%를 보유하고 있다. 지분법이익으로 이들의 실적이 한국조선해양에 반영됨에 따라 두 회사의 재무상태 변화의 추이가 상당부분 비슷해보인다.

# %% [markdown]
# ### 두 회사의 주가 비교 시각화

# %%
code = '009540'
stock_1 = fdr.DataReader(code, '2021-09') # fdr 모듈에서 DataReader 메서드를 이용하여 주가 불러오기
stock_1.reset_index(inplace = True)

# %%
stock_1
# Out:
#           Date    Open    High     Low   Close  Volume    Change
# 0   2021-09-01  117500  118000  113000  114000  705091 -0.037975
# 1   2021-09-02  114000  115000  112500  114000  428763  0.000000
# 2   2021-09-03  114000  114500  112000  113500  488582 -0.004386
# 3   2021-09-06  114000  115500  113000  114000  326789  0.004405
# 4   2021-09-07  115500  117500  115000  116500  443029  0.021930
# ..         ...     ...     ...     ...     ...     ...       ...
# 341 2023-01-19   74500   75500   74100   75200  110053 -0.001328
# 342 2023-01-20   75300   76500   74700   76300  124152  0.014628
# 343 2023-01-25   77200   77300   75900   76200   83928 -0.001311
# 344 2023-01-26   76000   77000   75300   76900  123154  0.009186
# 345 2023-01-27   77100   79800   76700   78800  281131  0.024707
#
# [346 rows x 7 columns]

# %%
grid = gridspec.GridSpec(2, 1)

# %%
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

stock_subsidiary = [stock, stock_1]
company = ['현대미포조선', '한국조선해양']
stock_features = ['Open', 'High', 'Low', 'Close'] 
for idx, data in enumerate(stock_subsidiary):
    ax = plt.subplot(grid[idx])
    for feature in stock_features:
        sns.lineplot(data = data,
                     x = 'Date',
                     y = feature, 
                     ax = ax) 
        plt.legend(labels = stock_features)
    ax.set_title(f'{company[idx]}')

# %% [markdown]
# - 현대미포조선 : 우크라이나 전쟁으로 선박 운임이 급등하고 있고 유럽이 러시아로부터 수입하던 석유제품을 더 먼 지역에서 조달하면서 선박 운항거리가 늘어난 실질 물동량 증가 효과로 MR탱커의 수주가 회복될 것이라는 기대감이 2022년 3분기 주가 상승에 담겨있음.
# - 한국조선해양 : 환율하락에 따른 외환 손실과 군산조선소 등에서의 자산 손상, 법인세 비용 등이 발생하면서 현금 유출 없는 장부상 손실이 나타나 지난해 순이익이 적자 전환됨. 또한, 코로나19 장기화에 따른 수주 가뭄 직격탄을 맞음. 이와 같은 이유들이 주가 하락에 반영된 것으로 보임.

# %% [markdown]
# ### 경쟁사: 대우조선해양(042660), 삼성중공업(010140)

# %% [markdown]
# - 재무제표 비교

# %%
# 대우조선해양 재무제표
code = '042660'
URL = f"https://finance.naver.com/item/main.naver?code={code}"
r = requests.get(URL)
df_2 = pd.read_html(r.text)[3]

# %%
df_2.set_index(df_2.columns[0], inplace = True) 
df_2.index.rename('주요재무정보', inplace = True)
df_2.columns = df_2.columns.droplevel(2) 

annual_date_2 = pd.DataFrame(df_2).xs('최근 연간 실적', axis = 1)
quarter_date_2 = pd.DataFrame(df_2).xs('최근 분기 실적', axis = 1)

# %%
new_quarter_date_2 = quarter_date_2.transpose().reset_index().rename(columns = {'index' : '날짜'})
new_quarter_date_2
# Out:
# 주요재무정보          날짜      매출액    영업이익   당기순이익  영업이익률   순이익률  ROE(지배주주)     부채비율  \
# 0          2021.09   9597.0  -190.0  -545.0  -1.98  -5.68     -44.81   297.31
# 1          2021.12  13557.0 -5153.0 -3984.0 -38.01 -29.39     -55.85   379.04
# 2          2022.03  12455.0 -4701.0 -4918.0 -37.75 -39.49     -72.99   523.16
# 3          2022.06  11841.0  -995.0 -1761.0  -8.40 -14.87     -53.69   676.45
# 4          2022.09   9815.0 -6278.0 -6466.0 -63.97 -65.89     -98.55  1290.83
# 5       2022.12(E)  17094.0  -445.0  -130.0  -2.60  -0.76        NaN      NaN
#
# 주요재무정보   당좌비율     유보율  EPS(원)  PER(배)   BPS(원)  PBR(배)  주당배당금(원)  시가배당률(%)  \
# 0       45.50 -112.29  -508.0   -1.95  24028.0    1.12       NaN       NaN
# 1       43.45 -181.66 -3713.0   -1.45  20672.0    1.12       NaN       NaN
# 2       36.18 -272.85 -4584.0   -1.36  16095.0    1.54       NaN       NaN
# 3       31.31 -305.38 -1641.0   -2.30  14434.0    1.66       NaN       NaN
# ...

# %%
# 삼성중공업 재무제표
code = '010140'
URL = f"https://finance.naver.com/item/main.naver?code={code}"
r = requests.get(URL)
df_3 = pd.read_html(r.text)[3]

# %%
df_3.set_index(df_3.columns[0], inplace = True) 
df_3.index.rename('주요재무정보', inplace = True)
df_3.columns = df_3.columns.droplevel(2) 

annual_date_3 = pd.DataFrame(df_3).xs('최근 연간 실적', axis = 1)
quarter_date_3 = pd.DataFrame(df_3).xs('최근 분기 실적', axis = 1)

# %%
new_quarter_date_3 = quarter_date_3.transpose().reset_index().rename(columns = {'index' : '날짜'}) 
new_quarter_date_3
# Out:
# 주요재무정보          날짜      매출액    영업이익   당기순이익  영업이익률   순이익률  ROE(지배주주)    부채비율  \
# 0          2021.09  14854.0 -1102.0 -1238.0  -7.42  -8.34     -44.48  318.26
# 1          2021.12  18465.0 -2571.0 -3450.0 -13.92 -18.68     -36.89  196.26
# 2          2022.03  14838.0  -949.0 -1039.0  -6.40  -7.00     -27.43  204.62
# 3          2022.06  14261.0 -2557.0  -391.0 -17.93  -2.74     -16.90  226.45
# 4          2022.09  14001.0 -1679.0 -2016.0 -11.99 -14.40     -18.15  275.39
# 5       2022.12(E)  17470.0  -905.0  -739.0  -5.18  -4.23        NaN     NaN
#
# 주요재무정보   당좌비율     유보율  EPS(원)  PER(배)  BPS(원)  PBR(배)  주당배당금(원)  시가배당률(%)  \
# 0       35.94  -16.85  -181.0   -2.53  4636.0    1.34       NaN       NaN
# 1       32.92  469.56  -432.0   -2.76  4813.0    1.18       NaN       NaN
# 2       32.42  457.85  -117.0   -4.21  4740.0    1.20       NaN       NaN
# 3       49.96  453.64   -42.0   -8.02  4969.0    1.22       NaN       NaN
# ...

# %%
grid = gridspec.GridSpec(3, 1)

# %%
# 수익성 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5) 

fin_competitors = [new_quarter_date, new_quarter_date_2, new_quarter_date_3]
company = ['현대미포조선', '대우조선해양', '삼성중공업']
fin_features =  ['매출액', '영업이익', '당기순이익', '영업이익률', '순이익률', 'ROE(지배주주)']
for idx, data in enumerate(fin_competitors):
    ax = plt.subplot(grid[idx])
    for feature in fin_features:
        sns.lineplot(data = data,
                     x = '날짜',
                     y = feature, 
                     ax = ax) 
        plt.legend(labels = fin_features)
    ax.set_title(f'{company[idx]}')
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 재무위험 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

fin_features_2 =  ['부채비율', '당좌비율']
for idx, data in enumerate(fin_competitors):
    ax = plt.subplot(grid[idx])
    for feature in fin_features_2:
        sns.lineplot(data = data,
                     x = '날짜',
                     y = feature, 
                     ax = ax)
        plt.legend(labels = fin_features_2)
    ax.set_title(f'{company[idx]}')
    plt.axhline(100, color='g', linestyle='--', linewidth = 2) 
    plt.axhline(200, color='r', linestyle='--', linewidth = 2) # 부채비율의 임계점인 100과 200을 표시

# %%
# 시장가치 관점
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

fin_features_3 = ['PER(배)', 'PBR(배)']
for idx, data in enumerate(fin_competitors):
    ax = plt.subplot(grid[idx])
    for feature in fin_features_3:
        sns.lineplot(data = data,
                     x = '날짜',
                     y = feature, 
                     ax = ax) 
        plt.legend(labels = fin_features_3)
    ax.set_title(f'{company[idx]}')
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 수주 증가와 더불어 환율 역시 조선업계에 유리하게 책정
# - 시황은 대우조선해양과 삼성중공업에게도 호조로 작용하지만, 양사의 재무건전성은 크게 나아지지 않고 있어 불안한 입장
# - 두 경쟁사의 재무위험 관점에 집중해보자.
# - 대우조선해양 : 1분기 676%를 시작으로 꾸준히 증가하는 부채비율을 기록해 시장의 우려가 상당함
# - 삼성중공업 : 226%로 비교적 낮은 편이지만, 지난 2분기 기준 19분기 연속 적자를 기록하고 있어 향후 뒷심이 부족할 수 있다는 의견이 제기됨.

# %% [markdown]
# ### 주가비교

# %%
# 대우조선해양 주가
code = '042660'
stock_2 = fdr.DataReader(code, '2021-09') # fdr 모듈에서 DataReader 메서드를 이용하여 주가 불러오기
stock_2.reset_index(inplace = True)

# %%
stock_2
# Out:
#           Date   Open   High    Low  Close  Volume    Change
# 0   2021-09-01  28000  28300  27050  27200  398852 -0.030303
# 1   2021-09-02  27200  27700  26750  27000  359509 -0.007353
# 2   2021-09-03  26900  27400  26750  27150  180026  0.005556
# 3   2021-09-06  27100  27850  27050  27700  232607  0.020258
# 4   2021-09-07  27700  28400  27400  28250  361352  0.019856
# ..         ...    ...    ...    ...    ...     ...       ...
# 341 2023-01-19  19350  19550  19000  19250  140877 -0.010283
# 342 2023-01-20  19250  20250  19250  20000  431153  0.038961
# 343 2023-01-25  20100  20200  19950  20100  208507  0.005000
# 344 2023-01-26  20300  20450  19950  20400  262390  0.014925
# 345 2023-01-27  20400  21150  20200  21050  429390  0.031863
#
# [346 rows x 7 columns]

# %%
# 삼성중공업 주가
code = '010140'
stock_3 = fdr.DataReader(code, '2021-09') # fdr 모듈에서 DataReader 메서드를 이용하여 주가 불러오기
stock_3.reset_index(inplace = True)

# %%
stock_3
# Out:
#           Date  Open  High   Low  Close   Volume    Change
# 0   2021-09-01  5854  5957  5817   5911  2250774  0.001525
# 1   2021-09-02  5910  5938  5789   5808  2810596 -0.017425
# 2   2021-09-03  5817  5882  5789   5873  2070198  0.011191
# 3   2021-09-06  5826  5920  5807   5855  2392984 -0.003065
# 4   2021-09-07  5854  5864  5770   5845  2094727 -0.001708
# ..         ...   ...   ...   ...    ...      ...       ...
# 341 2023-01-19  5070  5120  5060   5090  1252176 -0.003914
# 342 2023-01-20  5090  5150  5070   5130  1591799  0.007859
# 343 2023-01-25  5160  5180  5140   5180  2858773  0.009747
# 344 2023-01-26  5190  5190  5130   5170  1851224 -0.001931
# 345 2023-01-27  5170  5310  5150   5260  7182051  0.017408
#
# [346 rows x 7 columns]

# %%
plt.figure(figsize = (28, 18))
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)

stock_competitors = [stock, stock_2, stock_3]
company = ['현대미포조선', '대우조선해양', '삼성중공업']
stock_features = ['Open', 'High', 'Low', 'Close'] 
for idx, data in enumerate(stock_competitors):
    ax = plt.subplot(grid[idx])
    for feature in stock_features:
        sns.lineplot(data = data,
                     x = 'Date',
                     y = feature, 
                     ax = ax) 
        plt.legend(labels = stock_features)
    ax.set_title(f'{company[idx]}')

# %% [markdown]
# - 대우조선해양의 경우 2022년 9월 21년 만에 오너십이 생기는 대우조선해양의 경우 매각 소식이 알려진 직후 호재로 작용한 분위기였다. 이로 인해 전날 13.41% 뛰었지만 하루 만에 원점으로 복귀.
# - 차익 실현 매물과 함께 유상증자 규모가 커서 기존 주주 가치가 희석될 우려가 크다는 판단이 반영된 것으로 보임.
# - 삼성중공업은 조선 빅3 중에서도 드릴십 분야에 특히 강점을 갖고 있음. 드릴십은 해저유전을 탐사하는 데 쓰이는 장비인데 유가가 낮으면 해저유전 개발에 나서지 않으니 수요가 부족해지는데,
# - 문제는 국제유가가 서부텍사스산원유(WTI) 기준 배럴당 85달러선까지 올라왔는데도, 드릴십에 대한 인기가 시들하다는 점이다. 실제 올해 들어 경제 재개에 대한 기대와 함께 국제유가도 상승 추세를 지속하고 있지만, 한국 조선기업들의 드릴십 매각은 잇따라 취소되고 있어 우려스러움이 주가에 반영

# %% [markdown]
# ### 경쟁사와 현대미포조선(한국조선해양)
#
# - 조선 4사(대우조선해양·삼성중공업·케이조선·대한조선)는 한국조선해양이 부당한 방법으로 자사 인력을 채용하고 있다고 주장. 한국조선해양의 주요 계열사(현대중공업·현대미포조선·현대삼호중공업)를 공정거래위원회에 8월30일 신고함.
# - 대우조선해양과 삼성중공업이 차세대 친환경 엔진 공동개발에 나서면서 대립각이 더욱이 선명해지는 모습.
# - HSD엔진과 엔진 공동 개발 협약을 맺은 대우조선해양과 삼성중공업은 친환경 엔진 공동개발 외에도 협력 가능한 아이템을 발굴, 장기적인 협업까지 구상 중

# %% [markdown]
# ### 조선업 분위기
# - 이는 다른 산업에 비해 조선업은 오랜 시간 불황으로 어려움 겪어왔으며 최근 시황이 좋아지자 조선사간 경쟁이 치열해지는 것처럼 보임
# - 사업 규모상 한국조선해양이 월등한 1위일 수밖에 없어 경쟁 조선사의 고민이 클 것으로 보임
